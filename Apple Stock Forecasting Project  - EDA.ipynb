# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
apple_stk=pd.read_csv("C:\\Users\\Moideen Ovungal\\AAPL.csv")

# %%
apple_stk
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 2006  2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# 1     65005500
# 2     67817400
# 3     79573200
# 4     98506100
# ...        ...
# 2006  24643000
# 2007  12119700
# 2008  23280300
# 2009  36566500
# 2010  36028600
#
# [2011 rows x 7 columns]

# %%
apple_stk.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %%
apple_stk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   object
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.1+ KB

# %%
apple_stk.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
apple_stk.duplicated().sum()
# Out:
# 0

# %%
apple_stk.Close.plot()
# Out:
# <AxesSubplot:>

# %%
apple_stk.Open.plot()
# Out:
# <AxesSubplot:>

# %%
apple_stk.High.plot()
# Out:
# <AxesSubplot:>

# %%
apple_stk.Low.plot()
# Out:
# <AxesSubplot:>

# %%
apple_stk['Adj Close'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In all above plots we can observe upward exponential trend with multiplicative seasonality

# %%
apple_stk['Volume'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In above volume plot we can observe downward trend

# %%
apple_stk.Close.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# In above histogram, we can see more observations are between 50 to 125 range, data is right skewed and skewness is positive

# %%
apple_stk.Close.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
apple_stk['Date']=pd.to_datetime(apple_stk['Date'])

# %%
apple_stk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   datetime64[ns]
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage:
# 40 2012-03-01  78.309998  78.315712  76.967140  77.781425  67.213989
# 41 2012-03-02  77.748573  78.114288  77.502853  77.882858  67.301636
# 42 2012-03-05  77.917145  78.211426  75.142860  76.165718  65.817802
# 43 2012-03-06  74.808571  76.241432  73.745712  75.751427  65.459801
# 44 2012-03-07  76.685715  76.825714  74.757141  75.812859  65.512878
# 45 2012-03-08  76.384285  77.570000  76.017143  77.427139  66.907837
# 46 2012-03-09  77.744286  78.248573  77.587143  77.881432  67.300438
# 47 2012-03-12  78.425713  78.857140  78.142860  78.857140  68.143532
# 48 2012-03-13  79.648575  81.168571  79.392860  81.157143  70.131050
# 49 2012-03-14  82.578575  84.959999  82.199997  84.225716  72.782761
#
#        Volume
# 0    75555200
# 1    65005500
# 2    67817400
# 3    79573200
# 4    98506100
# 5    64549100
# 6    53771200
# 7    53146800
# 8    56505400
# 9    60724300
# 10   69197800
# 11   65434600
# 12  103493600
# 13   76515600
# 14  136909500
# 15  239578500
# 16   80996300
# 17   74927300
# 18   94835300
# 19   97920900
# 20   67511500
# 21   46699100
# 22   71649900
# 23   62353200
# 24   79055900
# 25  101972500
# 26  221053700
# 27  157825500
# 28  129304000
# 29  115099600
# 30  376530000
# 31  236138000
# 32  133951300
# 33  151398800
# 34  120825600
# 35  142006900
# 36  103768000
# 37  136895500
# 38  150096800
# 39  238002800
# 40  170817500
# 41  107928100
# 42  202281100
# 43  202559700
# 44  199630200
# 45  129114300
# 46  104729800
# 47  101820600
# 48  172713800
# 49  354711000

# %%
apple_stk["Month"] = apple_stk.Date.dt.strftime("%b") # month extraction
apple_stk["Year"] = apple_stk.Date.dt.strftime("%Y") # year extraction
apple_stk["Day"] = apple_stk.Date.dt.strftime("%d") # Day extraction

# %%
apple_stk
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume Month  Year Day
# 0     75555200   Jan  2012  03
# 1     65005500   Jan  2012  04
# 2     67817400   Jan  2012  05
# 3     79573200   Jan  2012  06
# 4     98506100   Jan  2012  09
# ...        ...   ...   ...  ..
# 2006  24643000   Dec  2019  23
# 2007  12119700   Dec  2019  24
# 2008  23280300   Dec  2019  26
# 2009  36566500   Dec  2019  27
# 2010  36028600   Dec  2019  30
#
# [2011 rows x 10 columns]

# %%
apple_stk['Week'] = apple_stk['Date'].dt.isocalendar().week  # week extraction
apple_stk['Quarter'] = apple_stk['Date'].dt.quarter          # quarter extraction
apple_stk['Quarter_Info'] = apple_stk['Date'].dt.to_period('Q') # quarter with yr extraction

# %%
apple_stk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2011 non-null   datetime64[ns]
#  1   Open          2011 non-null   float64
#  2   High          2011 non-null   float64
#  3   Low           2011 non-null   float64
#  4   Close         2011 non-null   float64
#  5   Adj Close     2011 non-null   float64
#  6   Volume        2011 non-null   int64
#  7   Month         2011 non-null   object
#  8   Year          2011 non-null   object
#  9   Day           2011 non-null   object
#  10  Week          2011 non-null   UInt32
#  11  Quarter       2011 non-null   int64
#  12  Quarter_Info  2011 non-null   period[Q-DEC]
# dtypes: UInt32(1), datetime64[ns](1), float64(5), int64(2), object(3), period[Q-DEC](1)
# memory usage: 198.5+ KB

# %%
apple_stk
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume Month  Year Day  Week  Quarter Quarter_Info
# 0     75555200   Jan  2012  03     1        1       2012Q1
# 1     65005500   Jan  2012  04     1        1       2012Q1
# 2     67817400   Jan  2012  05     1        1       2012Q1
# 3     79573200   Jan  2012  06     1        1       2012Q1
# 4     98506100   Jan  2012  09     2        1       2012Q1
# ...        ...   ...   ...  ..   ...      ...          ...
# 2006  24643000   Dec  2019  23    52        4       2019Q4
# 2007  12119700   Dec  2019  24    52        4       2019Q4
# 2008  23280300   Dec  2019  26    52        4       2019Q4
# 2009  36566500   Dec  2019  27    52        4       2019Q4
# 2010  36028600   Dec  2019  30     1        4       2019Q4
#
# [2011 rows x 13 columns]

# %%
apple_stk['Quarter_Info']=apple_stk['Quarter_Info'].astype('object')

# %%
apple_stk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2011 non-null   datetime64[ns]
#  1   Open          2011 non-null   float64
#  2   High          2011 non-null   float64
#  3   Low           2011 non-null   float64
#  4   Close         2011 non-null   float64
#  5   Adj Close     2011 non-null   float64
#  6   Volume        2011 non-null   int64
#  7   Month         2011 non-null   object
#  8   Year          2011 non-null   object
#  9   Day           2011 non-null   object
#  10  Week          2011 non-null   UInt32
#  11  Quarter       2011 non-null   int64
#  12  Quarter_Info  2011 non-null   object
# dtypes: UInt32(1), datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 198.5+ KB

# %%
apple_stk.groupby(['Year'])['Year'].value_counts()
# Out:
# Year  Year
# 2012  2012    250
# 2013  2013    252
# 2014  2014    252
# 2015  2015    252
# 2016  2016    252
# 2017  2017    251
# 2018  2018    251
# 2019  2019    251
# Name: Year, dtype: int64

# %%
pd.options.display.max_rows=100

# %%
apple_stk.groupby(['Year'])['Month'].value_counts()
# Out:
# Year  Month
# 2012  Aug      23
#       Mar      22
#       May      22
#       Jul      21
#       Jun      21
#       Nov      21
#       Oct      21
#       Apr      20
#       Dec      20
#       Feb      20
#       Jan      20
#       Sep      19
# 2013  Oct      23
#       Apr      22
#       Aug      22
#       Jul      22
#       May      22
#       Dec      21
#       Jan      21
#       Jun      20
#       Mar      20
#       Nov      20
#       Sep      20
#       Feb      19
# 2014  Oct      23
#       Dec      22
#       Jul      22
#       Apr      21
#       Aug      21
#       Jan      21
#       Jun      21
#       Mar      21
#       May      21
#       Sep      21
#       Feb      19
#       Nov      19
# 2015  Dec      22
#       Jul      22
#       Jun      22
#       Mar      22
#       Oct      22
#       Apr      21
#       Aug      21
#       Sep      21
#       Jan      20
#       May      20
#       Nov      20
#       Feb      19
# 2016  Aug      23
#       Jun      22
#       Mar      22
#       Apr      21
#       Dec      21
#       May      21
#       Nov      21
#       Oct      21
#       Sep      21
#       Feb      20
#       Jul      20
#       Jan      19
# 2017  Aug      23
#       Mar      23
#       Jun      22
#       May      22
#       Oct      22
#       Nov      21
#       Dec      20
#       Jan      20
#       Jul      20
#       Sep      20
#       Apr      19
#       Feb      19
# 2018  Aug      23
#       Oct      23
#       May      22
#       Apr      21
#       Jan      21
#       Jul      21
#       Jun      21
#       Mar      21
#       Nov      21
#       Dec      19
#       Feb      19
#       Sep      19
# 2019  Oct      23
#       Aug      22
#       Jul      22
#       May      22
#       Apr      21
#       Jan      21
#       Mar      21
#       Dec      20
#       Jun      20
#       Nov      20
#       Sep      20
#       Feb      19
# Name: Month, dtype: int64

# %%
apple_stk.groupby(['Year','Month'])['Day'].min()
# Out:
# Year  Month
# 2012  Apr      02
#       Aug      01
#       Dec      03
#       Feb      01
#       Jan      03
#       Jul      02
#       Jun      01
#       Mar      01
#       May      01
#       Nov      01
#       Oct      01
#       Sep      04
# 2013  Apr      01
#       Aug      01
#       Dec      02
#       Feb      01
#       Jan      02
#       Jul      01
#       Jun      03
#       Mar      01
#       May      01
#       Nov      01
#       Oct      01
#       Sep      03
# 2014  Apr      01
#       Aug      01
#       Dec      01
#       Feb      03
#       Jan      02
#       Jul      01
#       Jun      02
#       Mar      03
#       May      01
#       Nov      03
#       Oct      01
#       Sep      02
# 2015  Apr      01
#       Aug      03
#       Dec      01
#       Feb      02
#       Jan      02
#       Jul      01
#       Jun      01
#       Mar      02
#       May      01
#       Nov      02
#       Oct      01
#       Sep      01
# 2016  Apr      01
#       Aug      01
#       Dec      01
#       Feb      01
#       Jan      04
#       Jul      01
#       Jun      01
#       Mar      01
#       May      02
#       Nov      01
#       Oct      03
#       Sep      01
# 2017  Apr      03
#       Aug      01
#       Dec      01
#       Feb      01
#       Jan      03
#       Jul      03
#       Jun      01
#       Mar      01
#       May      01
#       Nov      01
#       Oct      02
#       Sep      01
# 2018  Apr      02
#       Aug      01
#       Dec      03
#       Feb      01
#       Jan      02
#       Jul      02
#       Jun      01
#       Mar      01
#       May      01
#       Nov      01
#       Oct      01
#       Sep      04
# 2019  Apr      01
#       Aug      01
#       Dec      02
#       Feb      01
#       Jan      02
#       Jul      01
#       Jun      03
#       Mar      01
#       May      01
#       Nov      01
#       Oct      01
#       Sep      03
# Name: Day, dtype: object

# %%
apple_stk.groupby(['Year','Month'])['Day'].max()
# Out:
# Year  Month
# 2012  Apr      30
#       Aug      31
#       Dec      31
#       Feb      29
#       Jan      31
#       Jul      31
#       Jun      29
#       Mar      30
#       May      31
#       Nov      30
#       Oct      31
#       Sep      28
# 2013  Apr      30
#       Aug      30
#       Dec      31
#       Feb      28
#       Jan      31
#       Jul      31
#       Jun      28
#       Mar      28
#       May      31
#       Nov      29
#       Oct      31
#       Sep      30
# 2014  Apr      30
#       Aug      29
#       Dec      31
#       Feb      28
#       Jan      31
#       Jul      31
#       Jun      30
#       Mar      31
#       May      30
#       Nov      28
#       Oct      31
#       Sep      30
# 2015  Apr      30
#       Aug      31
#       Dec      31
#       Feb      27
#       Jan      30
#       Jul      31
#       Jun      30
#       Mar      31
#       May      29
#       Nov      30
#       Oct      30
#       Sep      30
# 2016  Apr      29
#       Aug      31
#       Dec      30
#       Feb      29
#       Jan      29
#       Jul      29
#       Jun      30
#       Mar      31
#       May      31
#       Nov      30
#       Oct      31
#       Sep      30
# 2017  Apr      28
#       Aug      31
#       Dec      29
#       Feb      28
#       Jan      31
#       Jul      31
#       Jun      30
#       Mar      31
#       May      31
#       Nov      30
#       Oct      31
#       Sep      29
# 2018  Apr      30
#       Aug      31
#       Dec      31
#       Feb      28
#       Jan      31
#       Jul      31
#       Jun      29
#       Mar      29
#       May      31
#       Nov      30
#       Oct      31
#       Sep      28
# 2019  Apr      30
#       Aug      30
#       Dec      30
#       Feb      28
#       Jan      31
#       Jul      31
#       Jun      28
#       Mar      29
#       May      31
#       Nov      29
#       Oct      31
#       Sep      30
# Name: Day, dtype: object

# %% [markdown]
# I found few missing records like 2nd sep, 2012, 2nd sep 2013, 1st Sep 2014, 2nd Jan 2017, 3rd Sep 2018, 2nd Sep 2019, 31st Dec 2019

# %%
plt.figure(figsize=(12,3))
sns.lineplot(x="Year",y="Close",data=apple_stk)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Close'>

# %% [markdown]
# In above line plot of Year , we can observe that apple stock has decreasing trend from 2012 to 2013 & 2015 to 2016 and it has increasing trend from 2013 to 2015 & 2016 to 2019. Overall we can see upward trend.

# %%
# Boxplot for year and Month
plt.figure(figsize=(12,10))
plt.subplot(311)
sns.boxplot(x="Year",y="Close",data=apple_stk)
plt.subplot(312)
sns.boxplot(x="Quarter",y="Close",data=apple_stk)
plt.subplot(313)
sns.boxplot(x="Month",y="Close",data=apple_stk)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Close'>

# %%
plt.figure(figsize=(8,3))
sns.lineplot(x="Month",y="Close",data=apple_stk)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Close'>

# %%
month1=apple_stk.groupby(['Year','Month'])['Close'].mean()
month1
plt.figure(figsize=(20,5))
month1.plot(color='green', marker='o', linestyle='dashed',linewidth=2, markersize=6)
plt.grid()
plt.show()

# %%
quar=apple_stk.groupby(['Year','Quarter_Info'])['Close'].mean()
print(quar)
# Out:
# Year  Quarter_Info
# 2012  2012Q1           71.954263
#       2012Q2           83.012879
#       2012Q3           91.506213
#       2012Q4           82.537696
# 2013  2013Q1           66.596333
#       2013Q2           61.534710
#       2013Q3           66.320781
#       2013Q4           75.567567
# 2014  2014Q1           76.086370
#       2014Q2           85.117529
#       2014Q3           98.163437
#       2014Q4          108.821250
# 2015  2015Q1          120.777049
#       2015Q2          127.938095
#       2015Q3          117.303438
#       2015Q4          114.299375
# 2016  2016Q1           99.655082
#       2016Q2           99.401250
#       2016Q3          105.866094
#       2016Q4          113.399048
# 2017  2017Q1          131.712580
#       2017Q2          147.875396
#       2017Q3          155.169048
#       2017Q4          167.148254
# 2018  2018Q1          172.191312
#       2018Q2          181.396563
#       2018Q3          208.300001
#       2018Q4          193.912064
# 2019  2019Q1          169.663770
#       2019Q2          194.892699
#       2019Q3          209.120781
#       2019Q4          256.752222
# Name: Close, dtype: float64

# %%
quar=apple_stk.groupby(['Quarter_Info'])['Close'].mean()
plt.figure(figsize=(12,3))
#plt.xticks(x, labels, rotation='vertical')
quar.plot(color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=10)
plt.show()
#sns.lineplot(x="Quarter_Info", y="Close",data=apple_stk)

# %%
quar1=apple_stk.groupby(['Quarter','Year'])['Close'].mean()
quar1
# Out:
# Quarter  Year
# 1        2012     71.954263
#          2013     66.596333
#          2014     76.086370
#          2015    120.777049
#          2016     99.655082
#          2017    131.712580
#          2018    172.191312
#          2019    169.663770
# 2        2012     83.012879
#          2013     61.534710
#          2014     85.117529
#          2015    127.938095
#          2016     99.401250
#          2017    147.875396
#          2018    181.396563
#          2019    194.892699
# 3        2012     91.506213
#          2013     66.320781
#          2014     98.163437
#          2015    117.303438
#          2016    105.866094
#          2017    155.169048
#          2018    208.300001
#          2019    209.120781
# 4        2012     82.537696
#          2013     75.567567
#          2014    108.821250
#          2015    114.299375
#          2016    113.399048
#          2017    167.148254
#          2018    193.912064
#          2019    256.752222
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(16,8))
sns.pointplot(data=apple_stk, x='Quarter',y='Close',hue='Year')
#sns.barplot(data=apple_stk, x='Quarter_Info',y='Close',hue='Year')
# Out:
# <AxesSubplot:xlabel='Quarter', ylabel='Close'>

# %%
plt.figure(figsize=(16,8))
sns.pointplot(data=apple_stk, x='Quarter_Info',y='Close',hue='Year')
# Out:
# <AxesSubplot:xlabel='Quarter_Info', ylabel='Close'>

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=apple_stk, x='Year',y='Close',hue='Quarter')
#sns.barplot(data=apple_stk, x='Quarter_Info',y='Close',hue='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Close'>

# %% [markdown]
# In above plot, we can observe 2013 & 2016 are having same pattern,
# 2014 & 2017 having same pattern,
# 2012 & 2018 are having same patteren.

# %%
quar1=apple_stk.groupby(['Quarter','Year'])['Close'].mean()
quar1
plt.figure(figsize=(12,3))
quar1.plot(color='green', marker='o', linestyle='dashed',linewidth=2, markersize=10)
plt.grid()
plt.show()

# %% [markdown]
# In above quarter plots, we can observe quarter 1, 2, 3 are having similar patterns over years and quarter 4 pattern is sightly changed with other quarters

# %%
quar1=apple_stk.groupby(['Quarter','Year'])['Close'].mean()
quar1
# Out:
# Quarter  Year
# 1        2012     71.954263
#          2013     66.596333
#          2014     76.086370
#          2015    120.777049
#          2016     99.655082
#          2017    131.712580
#          2018    172.191312
#          2019    169.663770
# 2        2012     83.012879
#          2013     61.534710
#          2014     85.117529
#          2015    127.938095
#          2016     99.401250
#          2017    147.875396
#          2018    181.396563
#          2019    194.892699
# 3        2012     91.506213
#          2013     66.320781
#          2014     98.163437
#          2015    117.303438
#          2016    105.866094
#          2017    155.169048
#          2018    208.300001
#          2019    209.120781
# 4        2012     82.537696
#          2013     75.567567
#          2014    108.821250
#          2015    114.299375
#          2016    113.399048
#          2017    167.148254
#          2018    193.912064
#          2019    256.752222
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(12,3))
sns.lineplot(x="Week",y="Close",data=apple_stk)
# Out:
# <AxesSubplot:xlabel='Week', ylabel='Close'>

# %%
week1=apple_stk.groupby(['Week'])['Close'].mean()
week1
plt.figure(figsize=(20,5))
week1.plot(color='green', marker='o', linestyle='dashed',linewidth=2, markersize=8)
plt.grid()
plt.show()

# %%
apple_stk
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume Month  Year Day  Week  Quarter Quarter_Info
# 0     75555200   Jan  2012  03     1        1       2012Q1
# 1     65005500   Jan  2012  04     1        1       2012Q1
# 2     67817400   Jan  2012  05     1        1       2012Q1
# 3     79573200   Jan  2012  06     1        1       2012Q1
# 4     98506100   Jan  2012  09     2        1       2012Q1
# ...        ...   ...   ...  ..   ...      ...          ...
# 2006  24643000   Dec  2019  23    52        4       2019Q4
# 2007  12119700   Dec  2019  24    52        4       2019Q4
# 2008  23280300   Dec  2019  26    52        4       2019Q4
# 2009  36566500   Dec  2019  27    52        4       2019Q4
# 2010  36028600   Dec  2019  30     1        4       2019Q4
#
# [2011 rows x 13 columns]

# %%
plt.figure(figsize=(12,3))
sns.pointplot(x="Year",y="Volume",data=apple_stk)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Volume'>

# %% [markdown]
# In above line plot we can observe decreasing or downward trend in the volume.

# %%
plt.figure(figsize=(12,8))
heatmap_yr_month = pd.pivot_table(data=apple_stk,values="Close",index="Year",columns="Month",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_yr_month,annot=True,fmt="g") #fmt is format of the grid values
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Year'>

# %% [markdown]
# # Lag Plots

# %%
from pandas.plotting import lag_plot
lag_plot(apple_stk['Close'],lag=1)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(apple_stk['Close'],lag=7)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 7)'>

# %%
lag_plot(apple_stk['Close'],lag=15)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 15)'>

# %%
lag_plot(apple_stk['Close'],lag=30)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 30)'>

# %% [markdown]
# In above lag plots, we can see strong positive correlation, lag value is increasing speard also increasing.
# lag=1 is having strong correlation.

# %% [markdown]
# # Time series decomposition plot

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add = seasonal_decompose(apple_stk['Close'], model='multiplicative', period=30)
fig = plt.figure()  
fig = decompose_ts_add.plot()  
fig.set_size_inches(16, 9)

# %% [markdown]
# We can observe trend and seasonality clearly in above plots. So, we can say the data is non-stationary.

# %%
## Dicky Fuller Test
from statsmodels.tsa.stattools import adfuller
adfuller(apple_stk['Close'])
# Out:
# (1.2193701254378024,
#  0.996117017803201,
#  9,
#  2001,
#  {'1%': -3.433622218212895,
#   '5%': -2.8629854902259004,
#   '10%': -2.5675395171404802},
#  8633.09680956294)

# %% [markdown]
# We can see the probability value is more than 0.05. So we can say it is non-stationary data.

# %% [markdown]
# # ACF and PACF Plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(apple_stk.Close, lags=7)
plot_acf(apple_stk.Close, lags=30)
plt.show()

# %% [markdown]
# We can see all the lags are beyond the blue color zone, so we can say the data is non-stationary.

# %%
plot_pacf(apple_stk.Close, lags=7)
plot_pacf(apple_stk.Close, lags=30)
plt.show()
# Out:
# C:\Users\Moideen Ovungal\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# C:\Users\Moideen Ovungal\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# We can see only two lags are significant in above PACF plot , so we can apply ARIMA model for this data.

# %%
apple_stk['Close_diff']=apple_stk['Close'].diff()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(apple_stk.Close_diff)
plot_pacf(apple_stk.Close_diff)
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2475: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# C:\Users\admin\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 23   62353200   Feb  2012  06     6        1       2012Q1    0.612854
# 24   79055900   Feb  2012  07     6        1       2012Q1    0.694291
# 25  101972500   Feb  2012  08     6        1       2012Q1    1.121429
# 26  221053700   Feb  2012  09     6        1       2012Q1    2.355713
# 27  157825500   Feb  2012  10     6        1       2012Q1    0.035713
# 28  129304000   Feb  2012  13     7        1       2012Q1    1.311432
# 29  115099600   Feb  2012  14     7        1       2012Q1    0.979996
# 30  376530000   Feb  2012  15     7        1       2012Q1   -1.684288
# 31  236138000   Feb  2012  16     7        1       2012Q1    0.648575
# 32  133951300   Feb  2012  17     7        1       2012Q1   -0.012856
# 33  151398800   Feb  2012  21     8        1       2012Q1    1.818573
# 34  120825600   Feb  2012  22     8        1       2012Q1   -0.258575
# 35  142006900   Feb  2012  23     8        1       2012Q1    0.478569
# 36  103768000   Feb  2012  24     8        1       2012Q1    0.860000
# 37  136895500   Feb  2012  27     9        1       2012Q1    0.478577
# 38  150096800   Feb  2012  28     9        1       2012Q1    1.378570
# 39  238002800   Feb  2012  29     9        1       2012Q1    1.004288
# 40  170817500   Mar  2012  01     9        1       2012Q1    0.289993
# 41  107928100   Mar  2012  02     9        1       2012Q1    0.101433
# 42  202281100   Mar  2012  05    10        1       2012Q1   -1.717140
# 43  202559700   Mar  2012  06    10        1       2012Q1   -0.414291
# 44  199630200   Mar  2012  07    10        1       2012Q1    0.061432
# 45  129114300   Mar  2012  08    10        1       2012Q1    1.614280
# 46  104729800   Mar  2012  09    10        1       2012Q1    0.454293
# 47  101820600   Mar  2012  12    11        1       2012Q1    0.975708
# 48  172713800   Mar  2012  13    11        1       2012Q1    2.300003
# 49  354711000   Mar  2012  14    11        1       2012Q1    3.068573

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add = seasonal_decompose((apple_stk.Close_diff[1:]),period=15)
fig = plt.figure()  
fig = decompose_ts_add.plot()  
fig.set_size_inches(16, 9)

# %%
apple_stk['Close_diff2']=apple_stk['Close_diff'].diff()

# %%
apple_stk['Close_diff2']
# Out:
# 0            NaN
# 1            NaN
# 2       0.339996
# 3      -0.031426
# 4      -0.720000
#           ...
# 2006    5.139985
# 2007   -4.290009
# 2008    5.370026
# 2009   -5.750031
# 2010    1.830017
# Name: Close_diff2, Length: 2011, dtype: float64

# %%
apple_stk['Close_diff2'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(apple_stk['Close_diff2'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Close_diff2', ylabel='Density'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add = seasonal_decompose((apple_stk.Close_diff2[2:]),period=30)
fig = plt.figure()  
fig = decompose_ts_add.plot()  
fig.set_size_inches(16, 9)

# %%
#testing for stationary
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(apple_stk['Close'])

# %%
#H0= it is non stationary
#H1= it is stationary

def adfuller_test(Close):
    result=adfuller(Close)
    labels=['ADF Test statistics','p-value','lags used','number of observations used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value))
    if result[1] <=0.05:
        print("strong evidence against the null hypothesis")
# 9    60724300                0.698571                       NaN
# 10   69197800                0.630001                       NaN
# 11   65434600               -0.194287                       NaN
# 12  103493600               -1.064285                       NaN
# 13   76515600                1.015713                       NaN
# 14  136909500               -1.000000                       NaN
# 15  239578500                3.750000                       NaN
# 16   80996300               -0.290001                       NaN
# 17   74927300                0.378574                       NaN
# 18   94835300                0.818570                       NaN
# 19   97920900                0.495712                       NaN
# 20   67511500               -0.041428                       NaN
# 21   46699100               -0.152855                  6.270000
# 22   71649900                0.651428                  6.605712
# 23   62353200                0.612854                  6.562854
# 24   79055900                0.694291                  6.632859
# 25  101972500                1.121429                  7.850002
# 26  221053700                2.355713                  9.990002
# 27  157825500                0.035713                 10.124286
# 28  129304000                1.311432                 11.601433
# 29  115099600                0.979996                 12.807141
#
#     seasonality first difference
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                      6.270000
# 22                      6.605712
# 23                      6.562854
# 24                      6.632859
# 25                      7.850002
# 26                      9.990002
# 27                     10.124286
# 28                     11.601433
# 29                     12.807141

# %%
adfuller_test(apple_stk['close monthly difference'].dropna())
# Out:
# ADF Test statistics : -4.724367118857399
# p-value : 7.571656802987638e-05
# lags used : 24
# number of observations used : 1965
# strong evidence against the null hypothesis

# %%
apple_stk['close monthly difference'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Auto Regressive Model

# %%
pip install --upgrade --no-deps statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\moideen ovungal\anaconda3\lib\site-packages (0.13.2)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-win_amd64.whl (9.2 MB)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.2
#     Uninstalling statsmodels-0.13.2:
#       Successfully uninstalled statsmodels-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Moideen Ovungal\\anaconda3\\Lib\\site-packages\\~tatsmodels\\tsa\\_innovations.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import statsmodels.api as sm

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig=plt.figure(figsize=(12,8))
ax1=fig.add_subplot(211)
fig=sm.graphics.tsa.plot_acf(apple_stk['close monthly difference'].iloc[22:],lags=40,ax=ax1)
ax2=fig.add_subplot(212)
fig=sm.graphics.tsa.plot_pacf(apple_stk['close monthly difference'].iloc[22:],lags=40,ax=ax2)
# Out:
# C:\Users\Moideen Ovungal\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.arima.ARIMA(apple_stk['Close'], order=(1,1,2))
result = model.fit()

# %%
 result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2011
# Model:                 ARIMA(1, 1, 2)   Log Likelihood               -4369.300
# Date:                Tue, 04 Apr 2023   AIC                           8746.600
# Time:                        17:19:36   BIC                           8769.023
# Sample:                             0   HQIC                          8754.831
#                                - 2011
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1332      0.327      0.407      0.684      -0.508       0.774
# ma.L1         -0.1193      0.329     -0.363      0.717      -0.764       0.525
# ma.L2         -0.0486      0.017     -2.908      0.004      -0.081      -0.016
# sigma2         4.5252      0.071     63.355      0.000       4.385       4.665
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              3565.92
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.22   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
apple_stk['forecast']=result.predict(start=2000,end=2200,dynamic=True)
apple_stk[['Close','forecast']].plot(figsize=(12,18))
# Out:
# <AxesSubplot:>
